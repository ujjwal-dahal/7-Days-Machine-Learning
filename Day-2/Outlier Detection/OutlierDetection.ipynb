# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("person_data.csv")

# %%
df.head() #esle chai 1st 5 ota rows dincha
# Out:
#   Person_ID  Age  Energy_Rate  Height  Weight
# 0      P001   56        58.26  177.90   61.88
# 1      P002   69        50.78  174.31   81.65
# 2      P003   46        71.17  159.03   69.29
# 3      P004   32        69.74  163.18   77.78
# 4      P005   60        64.67  178.88   64.13

# %%
df.sample(5)  #Esle chai random 5 ota rows dincha
# Out:
#    Person_ID  Age  Energy_Rate  Height  Weight
# 64      P065   34        84.62  173.36   99.27
# 83      P084   32        81.72  153.08   82.87
# 40      P041   20        60.15  160.40   78.52
# 22      P023   55        69.15  163.99   74.07
# 5       P006   25        50.70  176.05   76.57

# %%
# sns.displot(df["Age"])
plt.figure(figsize=(12,5)) #Each Figure ko width , height
sns.displot(df["Height"],kde=True)

sns.displot(df["Weight"],kde=True)
